# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
datasets_info = pd.read_csv('r_scripts/datasets/datasets_summary.csv')
datasets_info.head()
# Out:
#         Name  Nodes  Edges  Diameter   Density  Modularity  \
# 0       Cora   2708   5278        19  0.001440    0.640119
# 1   Citeseer   3312   4536        28  0.000827    0.540161
# 2     PubMed  19717  44324        18  0.000228    0.431771
# 3  Dancer 01   1649   7608         7  0.011198    0.637071
# 4  Dancer 02   2376  16364         9  0.005800    0.365100
#
#    Clustering.Coefficient    Betweeness     Closeness  Connected.Components  \
# 0                0.293182   6053.358198  1.490000e-06                    78
# 1                0.242996   5583.614130  1.920000e-07                   438
# 2                0.111689  52610.864740  8.130000e-06                     1
# 3                0.180228   2072.433596  1.742960e-04                     1
# 4                0.007575   3481.862374  5.310000e-05                     5
#
#    Communities
# 0            7
# 1            6
# 2            3
# 3            7
# 4            6

# %%
print(datasets_info[['Name','Nodes','Edges','Diameter','Modularity']].to_latex())
# Out:
# \begin{tabular}{llrrrr}
# \toprule
# {} &       Name &  Nodes &  Edges &  Diameter &  Modularity \\
# \midrule
# 0 &       Cora &   2708 &   5278 &        19 &    0.640119 \\
# 1 &   Citeseer &   3312 &   4536 &        28 &    0.540161 \\
# 2 &     PubMed &  19717 &  44324 &        18 &    0.431771 \\
# 3 &  Dancer 01 &   1649 &   7608 &         7 &    0.637071 \\
# 4 &  Dancer 02 &   2376 &  16364 &         9 &    0.365100 \\
# 5 &  Dancer 03 &   2282 &  22673 &         5 &    0.646483 \\
# 6 &   email\_eu &   1005 &  16064 &         7 &    0.288013 \\
# \bottomrule
# \end{tabular}

# %%
print(datasets_info[['Name','Density','Clustering.Coefficient','Betweeness','Closeness','Connected.Components','Communities']].to_latex())
# Out:
# \begin{tabular}{llrrrrrr}
# \toprule
# {} &       Name &   Density &  Clustering.Coefficient &    Betweeness &     Closeness &  Connected.Components &  Communities \\
# \midrule
# 0 &       Cora &  0.001440 &                0.293182 &   6053.358198 &  1.490000e-06 &                    78 &            7 \\
# 1 &   Citeseer &  0.000827 &                0.242996 &   5583.614130 &  1.920000e-07 &                   438 &            6 \\
# 2 &     PubMed &  0.000228 &                0.111689 &  52610.864740 &  8.130000e-06 &                     1 &            3 \\
# 3 &  Dancer 01 &  0.011198 &                0.180228 &   2072.433596 &  1.742960e-04 &                     1 &            7 \\
# 4 &  Dancer 02 &  0.005800 &                0.007575 &   3481.862374 &  5.310000e-05 &                     5 &            6 \\
# 5 &  Dancer 03 &  0.008712 &                0.307893 &   2242.710780 &  1.488700e-04 &                     1 &            5 \\
# 6 &   email\_eu &  0.031841 &                0.450451 &    766.789055 &  4.540000e-05 &                    20 &           42 \\
# \bottomrule
# \end{tabular}

# %%
results = pd.read_csv('experiment_results.csv')
results = results[results['method'] != 'Louvain-igraph']

results.head()
# Out:
#      dataset modification  percentage      method      metric      value
# 4  Dancer 01   random asc         0.0  Fastgreedy           P   8.000000
# 5  Dancer 01   random asc         0.0  Fastgreedy        P*/P   0.750000
# 6  Dancer 01   random asc         0.0  Fastgreedy  Modularity   0.640525
# 7  Dancer 01   random asc         0.0  Fastgreedy         NMI   0.759245
# 8  Dancer 01   random asc         0.0     Infomap           P  99.000000

# %%
results['dataset'].unique()
# Out:
# array(['Dancer 01', 'Dancer 03', 'Cora', 'Email EU'], dtype=object)

# %%
# This for cycle is for saving images
for metric in ['P*/P','NMI']:
    for dataset in ['Dancer 01', 'Dancer 03', 'Cora']:
        for modification in results['modification'].unique():
            data = results[(results['metric'] == metric) &
                           (results['modification'] == modification) &
                           (results['dataset'] == dataset)]

            columns = ['percentage']
            columns.extend(data['method'].unique())
            
            data = data[['percentage','method','value']]
            data = data.pivot(index=['percentage'], columns=['method'])
            data.columns = ['_'.join(col).replace('value_','') for col in data.columns.values]
            data = data.reset_index()
            print('---------------------------------------------------------------------------------')
            print(metric,modification,dataset)
            print('\\begin{table}[H]')
            print(data.to_latex(index=False, float_format="{:0.3f}".format))
            print('\caption{Change of $P^{*}/P$ with random removal for '+dataset+'.}')
            print('\\end{table}')
            print('---------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------------
# P*/P random asc Dancer 01
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.750 &    0.061 &              1.000 &    0.667 \\
#       0.100 &       0.300 &    0.051 &              0.375 &    0.300 \\
#       0.200 &       0.158 &    0.045 &              0.188 &    0.167 \\
#       0.300 &       0.086 &    0.036 &              0.092 &    0.090 \\
#       0.400 &       0.058 &    0.028 &              0.067 &    0.062 \\
#       0.500 &       0.036 &    0.021 &              0.038 &    0.037 \\
#       0.600 &       0.025 &    0.016 &              0.024 &    0.025 \\
#       0.700 &       0.016 &    0.012 &              0.014 &    0.016 \\
#       0.800 &       0.010 &    0.009 &              0.009 &    0.010 \\
#       0.900 &       0.006 &    0.006 &              0.006 &    0.006 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Dancer 01.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# P*/P betweenness asc Dancer 01
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.750 &    0.061 &              1.000 &    0.667 \\
#       0.100 &       0.375 &    0.057 &              0.500 &    0.353 \\
#       0.200 &       0.150 &    0.041 &              0.171 &    0.150 \\
#       0.300 &       0.087 &    0.035 &              0.107 &    0.094 \\
#       0.400 &       0.067 &    0.030 &              0.071 &    0.068 \\
#       0.500 &       0.037 &    0.021 &              0.037 &    0.037 \\
#       0.600 &       0.024 &    0.016 &              0.024 &    0.025 \\
#       0.700 &       0.016 &    0.012 &              0.015 &    0.016 \\
#       0.800 &       0.010 &    0.009 &              0.009 &    0.011 \\
#       0.900 &       0.006 &    0.006 &              0.006 &    0.006 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Dancer 01.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# P*/P betweenness desc Dancer 01
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.750 &    0.062 &              1.000 &    0.667 \\
#       0.100 &       0.200 &    0.048 &              0.222 &    0.200 \\
#       0.200 &       0.102 &    0.037 &              0.107 &    0.100 \\
#       0.300 &       0.059 &    0.029 &              0.062 &    0.059 \\
#       0.400 &       0.036 &    0.022 &              0.038 &    0.036 \\
#       0.500 &       0.026 &    0.018 &              0.026 &    0.026 \\
#       0.600 &       0.017 &    0.013 &              0.017 &    0.017 \\
#       0.700 &       0.012 &    0.010 &              0.011 &    0.012 \\
#       0.800 &       0.008 &    0.007 &              0.008 &    0.008 \\
#       0.900 &       0.005 &    0.005 &              0.005 &    0.006 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Dancer 01.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# P*/P random asc Dancer 03
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.556 &    0.057 &              1.000 &    0.556 \\
#       0.100 &       0.500 &    0.054 &              0.833 &    0.455 \\
#       0.200 &       0.143 &    0.041 &              0.172 &    0.147 \\
#       0.300 &       0.135 &    0.039 &              0.143 &    0.132 \\
#       0.400 &       0.056 &    0.026 &              0.059 &    0.056 \\
#       0.500 &       0.034 &    0.020 &              0.036 &    0.034 \\
#       0.600 &       0.023 &    0.015 &              0.024 &    0.023 \\
#       0.700 &       0.014 &    0.011 &              0.014 &    0.014 \\
#       0.800 &       0.009 &    0.007 &              0.009 &    0.009 \\
#       0.900 &       0.005 &    0.005 &              0.005 &    0.005 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Dancer 03.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# P*/P betweenness asc Dancer 03
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.556 &    0.058 &              1.000 &    0.500 \\
#       0.100 &       0.385 &    0.051 &              0.714 &    0.417 \\
#       0.200 &       0.156 &    0.043 &              0.200 &    0.172 \\
#       0.300 &       0.106 &    0.034 &              0.125 &    0.104 \\
#       0.400 &       0.062 &    0.027 &              0.068 &    0.060 \\
#       0.500 &       0.033 &    0.020 &              0.035 &    0.033 \\
#       0.600 &       0.022 &    0.015 &              0.023 &    0.022 \\
#       0.700 &       0.015 &    0.011 &              0.015 &    0.015 \\
#       0.800 &       0.009 &    0.007 &              0.009 &    0.009 \\
#       0.900 &       0.005 &    0.004 &              0.005 &    0.005 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Dancer 03.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# P*/P betweenness desc Dancer 03
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.556 &    0.058 &              1.000 &    0.556 \\
#       0.100 &       0.104 &    0.037 &              0.119 &    0.102 \\
#       0.200 &       0.040 &    0.023 &              0.042 &    0.041 \\
#       0.300 &       0.019 &    0.014 &              0.019 &    0.019 \\
#       0.400 &       0.012 &    0.010 &              0.012 &    0.012 \\
#       0.500 &       0.009 &    0.008 &              0.009 &    0.009 \\
#       0.600 &       0.007 &    0.006 &              0.007 &    0.007 \\
#       0.700 &       0.006 &    0.005 &              0.006 &    0.006 \\
#       0.800 &       0.004 &    0.004 &              0.004 &    0.004 \\
#       0.900 &       0.003 &    0.003 &              0.003 &    0.003 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Dancer 03.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# P*/P random asc Cora
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.067 &    0.022 &              0.029 &    0.066 \\
#       0.100 &       0.042 &    0.019 &              0.023 &    0.043 \\
#       0.200 &       0.029 &    0.015 &              0.019 &    0.029 \\
#       0.300 &       0.020 &    0.012 &              0.014 &    0.020 \\
#       0.400 &       0.014 &    0.010 &              0.011 &    0.014 \\
#       0.500 &       0.010 &    0.008 &              0.009 &    0.010 \\
#       0.600 &       0.007 &    0.006 &              0.007 &    0.007 \\
#       0.700 &       0.006 &    0.005 &              0.005 &    0.006 \\
#       0.800 &       0.004 &    0.004 &              0.004 &    0.004 \\
#       0.900 &       0.003 &    0.003 &              0.003 &    0.003 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Cora.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# P*/P betweenness asc Cora
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.067 &    0.022 &              0.030 &    0.068 \\
#       0.100 &       0.044 &    0.019 &              0.024 &    0.046 \\
#       0.200 &       0.029 &    0.016 &              0.018 &    0.029 \\
#       0.300 &       0.021 &    0.013 &              0.014 &    0.021 \\
#       0.400 &       0.014 &    0.010 &              0.011 &    0.014 \\
#       0.500 &       0.010 &    0.008 &              0.008 &    0.010 \\
#       0.600 &       0.008 &    0.007 &              0.007 &    0.008 \\
#       0.700 &       0.006 &    0.005 &              0.005 &    0.006 \\
#       0.800 &       0.004 &    0.004 &              0.004 &    0.004 \\
#       0.900 &       0.003 &    0.003 &              0.003 &    0.003 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Cora.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# P*/P betweenness desc Cora
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.067 &    0.022 &              0.029 &    0.069 \\
#       0.100 &       0.043 &    0.019 &              0.023 &    0.043 \\
#       0.200 &       0.029 &    0.016 &              0.018 &    0.029 \\
#       0.300 &       0.018 &    0.013 &              0.013 &    0.019 \\
#       0.400 &       0.013 &    0.010 &              0.010 &    0.014 \\
#       0.500 &       0.009 &    0.008 &              0.008 &    0.009 \\
#       0.600 &       0.007 &    0.006 &              0.006 &    0.007 \\
#       0.700 &       0.005 &    0.005 &              0.005 &    0.005 \\
#       0.800 &       0.004 &    0.004 &              0.004 &    0.004 \\
#       0.900 &       0.003 &    0.003 &              0.003 &    0.003 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Cora.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# NMI random asc Dancer 01
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.759 &    0.556 &              0.808 &    0.773 \\
#       0.100 &       0.685 &    0.523 &              0.766 &    0.728 \\
#       0.200 &       0.682 &    0.520 &              0.732 &    0.685 \\
#       0.300 &       0.626 &    0.476 &              0.615 &    0.631 \\
#       0.400 &       0.560 &    0.434 &              0.588 &    0.577 \\
#       0.500 &       0.544 &    0.423 &              0.517 &    0.550 \\
#       0.600 &       0.514 &    0.399 &              0.467 &    0.491 \\
#       0.700 &       0.450 &    0.373 &              0.410 &    0.439 \\
#       0.800 &       0.391 &    0.364 &              0.366 &    0.377 \\
#       0.900 &       0.363 &    0.367 &              0.368 &    0.363 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Dancer 01.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# NMI betweenness asc Dancer 01
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.759 &    0.556 &              0.791 &    0.784 \\
#       0.100 &       0.714 &    0.543 &              0.696 &    0.749 \\
#       0.200 &       0.659 &    0.514 &              0.713 &    0.671 \\
#       0.300 &       0.601 &    0.481 &              0.641 &    0.614 \\
#       0.400 &       0.598 &    0.442 &              0.636 &    0.581 \\
#       0.500 &       0.539 &    0.425 &              0.515 &    0.523 \\
#       0.600 &       0.487 &    0.393 &              0.485 &    0.472 \\
#       0.700 &       0.452 &    0.377 &              0.403 &    0.441 \\
#       0.800 &       0.407 &    0.368 &              0.379 &    0.388 \\
#       0.900 &       0.378 &    0.374 &              0.375 &    0.379 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Dancer 01.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# NMI betweenness desc Dancer 01
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.759 &    0.554 &              0.809 &    0.781 \\
#       0.100 &       0.686 &    0.534 &              0.771 &    0.716 \\
#       0.200 &       0.681 &    0.512 &              0.707 &    0.677 \\
#       0.300 &       0.621 &    0.494 &              0.651 &    0.636 \\
#       0.400 &       0.592 &    0.467 &              0.620 &    0.599 \\
#       0.500 &       0.558 &    0.445 &              0.556 &    0.559 \\
#       0.600 &       0.528 &    0.440 &              0.533 &    0.528 \\
#       0.700 &       0.502 &    0.436 &              0.497 &    0.500 \\
#       0.800 &       0.479 &    0.425 &              0.460 &    0.486 \\
#       0.900 &       0.430 &    0.407 &              0.418 &    0.429 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Dancer 01.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# NMI random asc Dancer 03
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.671 &    0.530 &              0.748 &    0.687 \\
#       0.100 &       0.678 &    0.519 &              0.724 &    0.672 \\
#       0.200 &       0.633 &    0.498 &              0.689 &    0.646 \\
#       0.300 &       0.610 &    0.467 &              0.642 &    0.601 \\
#       0.400 &       0.565 &    0.441 &              0.604 &    0.562 \\
#       0.500 &       0.555 &    0.452 &              0.578 &    0.558 \\
#       0.600 &       0.526 &    0.419 &              0.555 &    0.507 \\
#       0.700 &       0.463 &    0.392 &              0.481 &    0.464 \\
#       0.800 &       0.424 &    0.363 &              0.428 &    0.414 \\
#       0.900 &       0.381 &    0.329 &              0.359 &    0.378 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Dancer 03.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# NMI betweenness asc Dancer 03
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.671 &    0.532 &              0.753 &    0.683 \\
#       0.100 &       0.657 &    0.511 &              0.735 &    0.664 \\
#       0.200 &       0.625 &    0.491 &              0.675 &    0.639 \\
#       0.300 &       0.591 &    0.467 &              0.644 &    0.595 \\
#       0.400 &       0.574 &    0.446 &              0.620 &    0.569 \\
#       0.500 &       0.535 &    0.433 &              0.569 &    0.540 \\
#       0.600 &       0.517 &    0.420 &              0.536 &    0.517 \\
#       0.700 &       0.471 &    0.402 &              0.505 &    0.467 \\
#       0.800 &       0.416 &    0.371 &              0.419 &    0.413 \\
#       0.900 &       0.379 &    0.328 &              0.352 &    0.386 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Dancer 03.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# NMI betweenness desc Dancer 03
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.671 &    0.529 &              0.756 &    0.686 \\
#       0.100 &       0.653 &    0.511 &              0.683 &    0.651 \\
#       0.200 &       0.603 &    0.503 &              0.635 &    0.602 \\
#       0.300 &       0.590 &    0.503 &              0.606 &    0.593 \\
#       0.400 &       0.550 &    0.488 &              0.557 &    0.555 \\
#       0.500 &       0.529 &    0.482 &              0.537 &    0.529 \\
#       0.600 &       0.504 &    0.463 &              0.509 &    0.502 \\
#       0.700 &       0.483 &    0.438 &              0.485 &    0.483 \\
#       0.800 &       0.444 &    0.410 &              0.444 &    0.443 \\
#       0.900 &       0.397 &    0.378 &              0.397 &    0.397 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Dancer 03.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# NMI random asc Cora
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.465 &    0.413 &              0.422 &    0.458 \\
#       0.100 &       0.448 &    0.412 &              0.411 &    0.429 \\
#       0.200 &       0.449 &    0.400 &              0.415 &    0.434 \\
#       0.300 &       0.407 &    0.395 &              0.402 &    0.406 \\
#       0.400 &       0.408 &    0.392 &              0.394 &    0.386 \\
#       0.500 &       0.382 &    0.385 &              0.378 &    0.383 \\
#       0.600 &       0.388 &    0.384 &              0.389 &    0.387 \\
#       0.700 &       0.368 &    0.381 &              0.377 &    0.365 \\
#       0.800 &       0.372 &    0.376 &              0.379 &    0.371 \\
#       0.900 &       0.377 &    0.377 &              0.377 &    0.377 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Cora.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# NMI betweenness asc Cora
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.465 &    0.414 &              0.434 &    0.459 \\
#       0.100 &       0.461 &    0.412 &              0.414 &    0.443 \\
#       0.200 &       0.423 &    0.401 &              0.411 &    0.425 \\
#       0.300 &       0.409 &    0.394 &              0.403 &    0.408 \\
#       0.400 &       0.405 &    0.390 &              0.393 &    0.396 \\
#       0.500 &       0.389 &    0.386 &              0.390 &    0.382 \\
#       0.600 &       0.379 &    0.384 &              0.380 &    0.373 \\
#       0.700 &       0.376 &    0.380 &              0.379 &    0.375 \\
#       0.800 &       0.375 &    0.378 &              0.377 &    0.375 \\
#       0.900 &       0.377 &    0.377 &              0.377 &    0.377 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Cora.}
# \end{table}
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# NMI betweenness desc Cora
# \begin{table}[H]
# \begin{tabular}{rrrrr}
# \toprule
#  percentage &  Fastgreedy &  Infomap &  Label Propagation &  Louvain \\
# \midrule
#       0.000 &       0.465 &    0.414 &              0.424 &    0.450 \\
#       0.100 &       0.453 &    0.408 &              0.419 &    0.421 \\
#       0.200 &       0.444 &    0.405 &              0.410 &    0.436 \\
#       0.300 &       0.407 &    0.403 &              0.400 &    0.408 \\
#       0.400 &       0.424 &    0.404 &              0.401 &    0.420 \\
#       0.500 &       0.419 &    0.400 &              0.400 &    0.417 \\
#       0.600 &       0.416 &    0.401 &              0.399 &    0.417 \\
#       0.700 &       0.402 &    0.397 &              0.395 &    0.403 \\
#       0.800 &       0.397 &    0.393 &              0.393 &    0.397 \\
#       0.900 &       0.385 &    0.385 &              0.385 &    0.385 \\
# \bottomrule
# \end{tabular}
#
# \caption{Change of $P^{*}/P$ with random removal for Cora.}
# \end{table}
# ---------------------------------------------------------------------------------

# %%
data.columns
# Out:
# MultiIndex([('value',        'Fastgreedy'),
#             ('value',           'Infomap'),
#             ('value', 'Label Propagation'),
#             ('value',           'Louvain'),
#             ('value',    'Louvain-igraph')],
#            names=[None, 'method'])
